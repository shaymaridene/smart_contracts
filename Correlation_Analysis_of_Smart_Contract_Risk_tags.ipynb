# %% [markdown]
# <a href="https://colab.research.google.com/github/shaymaridene/smart_contracts/blob/main/Correlation_Analysis_of_Smart_Contract_Risk_tags.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implementation of Correlation Analysis in Smart Contract Security Data
#
# Welcome to the advanced section of our analysis series, where we focus on implementing correlation analysis for binary data using Python. In this notebook, we'll dive into calculating both the Phi coefficient and the Point-Biserial correlation, visualizing the results, and interpreting what these correlations tell us about the relationships between different risk tags in smart contract data.
#
# ## Objective
# Our goal is to enhance your ability to perform and understand advanced statistical analyses, preparing you for data-driven decision-making in cybersecurity or any field requiring detailed data insight.
#
# Before you begin, ensure you have a basic understanding of Python programming and familiarity with libraries such as pandas, matplotlib, and seaborn. If you're ready, let's start by setting up our environment and loading the data!

# %% [markdown]
# ### Step 1: Import libraries

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

# Ensure plots are displayed inline in the notebook
# %matplotlib inline

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ### Step 2: Download the dataset

# %% [markdown]
# Please note that the dataset that will be downloaded below is a dummy dataset that has been designed for the tutorial. You need to use the actualy dataset provided to you for the analysis

# %%
# !gdown 1NYR65tYzMe4Rwc0kFyTEj2nerJJFRf6n
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NYR65tYzMe4Rwc0kFyTEj2nerJJFRf6n
# To: /content/webacy_risk_dataset.xlsx
# 100% 28.2k/28.2k [00:00<00:00, 32.0MB/s]

# %%
print("Setup complete. Imported pandas, seaborn, and matplotlib. Downloaded Webacy dummy dataset.")
# Out:
# Setup complete. Imported pandas, seaborn, and matplotlib. Downloaded Webacy dummy dataset.

# %% [markdown]
# ### Step 3: Load the Data Section
#
# Now even though we have downloaded the dataset, we still need to load it into our Python environment. For this we will utilize the Pandas library.

# %%
# Loading the dataset

df = pd.read_excel('webacy_risk_dataset.xlsx')

# Display the first five rows of the dataframe
df.head()
# Out:
#                         Blog Post Link  \
# 0  https://exampleblockchain.com/post0
# 1  https://exampleblockchain.com/post1
# 2  https://exampleblockchain.com/post2
# 3  https://exampleblockchain.com/post3
# 4  https://exampleblockchain.com/post4
#
#                        Smart Contract Address  \
# 0  0xcf503b37935247688ca1677e8159d8943035eff0
# 1  0x23813d33e70199f0fa473eb27c2004556841f49a
# 2  0xaf811799367be2b0e35c9a4b464ff43c448ef43a
# 3  0x7fd55015930f5e012420d32ad0759f0a2baf7b29
# 4  0x2e3eb32e3412be9a14a6b8b23006063ea38c8de8
#
#                          Audit Website                     Source link 1  \
# 0  https://auditplatform.com/contract0  https://sourceinfo.com/detail159
# 1  https://auditplatform.com/contract1  https://sourceinfo.com/detail143
# 2  https://auditplatform.com/contract2  https://sourceinfo.com/detail179
# 3  https://auditplatform.com/contract3  https://sourceinfo.com/detail159
# 4  https://auditplatform.com/contract4  https://sourceinfo.com/detail121
#
#                       Source link 2                     Source link 3  \
# 0  https://sourceinfo.com/detail293  https://sourceinfo.com/detail351
# 1  https://sourceinfo.com/detail203  https://sourceinfo.com/detail377
# 2  https://sourceinfo.com/detail203  https://sourceinfo.com/detail382
# 3  https://sourceinfo.com/detail298  https://sourceinfo.com/detail317
# 4  https://sourceinfo.com/detail236  https://sourceinfo.com/detail303
#
#                  Chain  Is_closed_source  hidden_owner  anti_whale_modifiable  \
# 0              Polygon             False         False                  False
# 1  Binance Smart Chain             False          True                  False
# 2             Ethereum             False         False                   True
# 3              Polygon             False          True                   True
# 4             Ethereum             False         False                  False
#
#    ...  centralized_risk_high  centralized_risk_low  event_setter  \
# 0  ...                   True                  True         False
# 1  ...                  False                  True          True
# 2  ...                  False                 False          True
# 3  ...                  False                 False          True
# 4  ...                   True                 False         False
#
#    external_dependencies  immutable_states  reentrancy_without_eth_transfer  \
# 0                   True             False                            False
# 1                  False              True                            False
# 2                  False             False                             True
# 3                  False              True                             True
# 4                  False             False                            False
#
#    incorrect_inheritance_order  shadowing_local  events_maths  \
# 0                        False            False          True
# 1                        False             True          True
# 2                        False            False         False
# 3                         True             True          True
# 4                         True            False         False
#
#           Summary/rationale of risk tags marked true
# 0  Includes both buy and sell taxes, indicating t...
# 1  Includes both buy and sell taxes, indicating t...
# 2  Marked as honeypot due to suspicious transacti...
# 3  Includes both buy and sell taxes, indicating t...
# 4                                                NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Calculate Correlation
#
# To calculate the Phi coefficient, which is suitable for pairs of binary variables, we first need to establish a function that can handle this calculation:

# %%
def phi_coefficient(x, y):
    """Calculate the Phi coefficient for two binary variables."""
    # Create a contingency table
    contingency_table = pd.crosstab(x, y)
    # Calculate the phi coefficient from the contingency table
    chi2 = scipy.stats.chi2_contingency(contingency_table, correction=False)[0]
    n = np.sum(np.sum(contingency_table))
    phi = np.sqrt(chi2 / n)
    return phi

# Example calculation between two risk tags
phi = phi_coefficient(df['Is_honeypot'], df['anti_whale_modifiable'])
print(f"Phi Coefficient between 'Is_honeypot' and 'anti_whale_modifiable': {phi}")
# Out:
# Phi Coefficient between 'Is_honeypot' and 'anti_whale_modifiable': 0.026885923069231665

# %% [markdown]
# Phi value close to 0 indicates no correlation between the two columns.
#
# **Note:** Phi values range from -1 to 1. A negative value of Phi indicates that the variables are inversely related, or when one variable increases, the other decreases. On the other hand, positive values indicate that when one variable increases, so does the other.

# %% [markdown]
# Let's now define the risk columns of our dataset.

# %%
risk_columns = ['Is_closed_source', 'hidden_owner', 'anti_whale_modifiable',
       'Is_anti_whale', 'Is_honeypot', 'buy_tax', 'sell_tax',
       'slippage_modifiable', 'Is_blacklisted', 'can_take_back_ownership',
       'owner_change_balance', 'is_airdrop_scam', 'selfdestruct', 'trust_list',
       'is_whitelisted', 'is_fake_token', 'illegal_unicode', 'exploitation',
       'bad_contract', 'reusing_state_variable', 'encode_packed_collision',
       'encode_packed_parameters', 'centralized_risk_medium',
       'centralized_risk_high', 'centralized_risk_low', 'event_setter',
       'external_dependencies', 'immutable_states',
       'reentrancy_without_eth_transfer', 'incorrect_inheritance_order',
       'shadowing_local', 'events_maths']

# %% [markdown]
# Now we will calculate the phi coefficient for all the columns

# %%
risk_df = df[risk_columns]

# Create a DataFrame to store Phi coefficients
phi_matrix = pd.DataFrame(index=risk_df.columns, columns=risk_df.columns)

# Calculate Phi coefficient for each pair of binary variables
for var1 in risk_df.columns:
    for var2 in risk_df.columns:
        phi_matrix.loc[var1, var2] = phi_coefficient(risk_df[var1], risk_df[var2])

print("Phi coefficients calculated for all pairs of variables:")
phi_matrix
# Out:
# Phi coefficients calculated for all pairs of variables:
#                                 Is_closed_source hidden_owner  \
# Is_closed_source                             1.0     0.026364
# hidden_owner                            0.026364          1.0
# anti_whale_modifiable                   0.027713     0.073566
# Is_anti_whale                           0.148206     0.097518
# Is_honeypot                             0.004384     0.021788
# buy_tax                                 0.010199     0.095939
# sell_tax                                0.103033     0.044228
# slippage_modifiable                     0.096956     0.027871
# Is_blacklisted                          0.037474     0.027871
# can_take_back_ownership                 0.104751     0.182537
# owner_change_balance                    0.016773     0.044228
# is_airdrop_scam                         0.103033     0.129283
# selfdestruct                            0.275683     0.144123
# trust_list                              0.103033     0.129283
# is_whitelisted                          0.153025      0.18306
# is_fake_token                           0.060855     0.154175
# illegal_unicode                         0.053024     0.000846
# exploitation                            0.106052      0.03144
# bad_contract                            0.208145      0.12666
# reusing_state_variable                  0.066131     0.126043
# encode_packed_collision                 0.104751     0.098029
# encode_packed_parameters                 0.13332     0.055775
# centralized_risk_medium                 0.060855     0.027108
# centralized_risk_high                   0.058468     0.015248
# centralized_risk_low                    0.029735          0.0
# event_setter                            0.014284     0.028733
# external_dependencies                   0.109254     0.068945
# immutable_states                        0.012139     0.060327
# reentrancy_without_eth_transfer          0.08149     0.098815
# incorrect_inheritance_order             0.006554     0.000846
# shadowing_local                         0.022008     0.196785
# events_maths                            0.037474     0.014358
#
#                                 anti_whale_modifiable Is_anti_whale  \
# Is_closed_source                             0.027713      0.148206
# hidden_owner                                 0.073566      0.097518
# anti_whale_modifiable                             1.0      0.014778
# Is_anti_whale                                0.014778           1.0
# Is_honeypot                                  0.026886      0.197163
# buy_tax                                      0.062545      0.149414
# sell_tax                                      0.22531      0.142043
# slippage_modifiable                          0.064038      0.017023
# Is_blacklisted                               0.104568      0.138613
# can_take_back_ownership                      0.128152      0.006489
# owner_change_balance                         0.062042      0.101226
# is_airdrop_scam                              0.184493      0.021225
# selfdestruct                                  0.03847       0.12032
# trust_list                                   0.019592      0.019592
# is_whitelisted                                0.09688      0.067323
# is_fake_token                                0.149601      0.068296
# illegal_unicode                              0.111231      0.010555
# exploitation                                 0.084174      0.242992
# bad_contract                                 0.121566           0.0
# reusing_state_variable                       0.151826      0.151826
# encode_packed_collision                      0.196284      0.209261
# encode_packed_parameters                     0.047043       0.07462
# centralized_risk_medium                      0.027644      0.094313
# centralized_risk_high                        0.094313      0.068296
# centralized_risk_low                         0.081044      0.040522
# event_setter                                 0.047043       0.07462
# external_dependencies                        0.090987      0.008272
# immutable_states                             0.157159      0.157159
# reentrancy_without_eth_transfer              0.057553      0.023507
# incorrect_inheritance_order                   0.03004      0.091745
# shadowing_local                              0.064038      0.023507
# events_maths                                 0.098083      0.145098
#
#                                 Is_honeypot   buy_tax  sell_tax  \
# Is_closed_source                   0.004384  0.010199  0.103033
# hidden_owner                       0.021788  0.095939  0.044228
# anti_whale_modifiable              0.026886  0.062545   0.22531
# Is_anti_whale                      0.197163  0.149414  0.142043
# Is_honeypot                             1.0   0.12327  0.112872
# buy_tax                             0.12327       1.0  0.003455
# sell_tax                           0.112872  0.003455       1.0
# slippage_modifiable                0.067837  0.056606   0.09833
# Is_blacklisted                      0.15337  0.056606  0.062867
# can_take_back_ownership            0.085585  0.015447  0.085486
# owner_change_balance               0.035644  0.082918  0.107143
# is_airdrop_scam                    0.035644  0.046642  0.055195
# selfdestruct                       0.116149  0.010392  0.078128
# trust_list                         0.112872  0.126105  0.055195
# is_whitelisted                     0.101569  0.111192  0.101226
# is_fake_token                      0.023667  0.030969  0.151982
# illegal_unicode                    0.056129  0.087622  0.012916
# exploitation                       0.352501  0.104184  0.006317
# bad_contract                       0.073721  0.085749  0.040291
# reusing_state_variable             0.129983  0.127138  0.108175
# encode_packed_collision            0.135755  0.070371  0.004839
# encode_packed_parameters           0.085585  0.058356  0.004839
# centralized_risk_medium            0.023667  0.055056   0.07114
# centralized_risk_high              0.050291  0.184094   0.07114
# centralized_risk_low                    0.0  0.085749       0.0
# event_setter                       0.159365  0.015447  0.075808
# external_dependencies              0.165531  0.035007  0.016449
# immutable_states                   0.015048  0.035007  0.065795
# reentrancy_without_eth_transfer    0.005899  0.099489  0.022568
# incorrect_inheritance_order        0.017725  0.173526  0.174372
# shadowing_local                    0.005899  0.114927  0.183764
# events_maths                        0.15337  0.056606  0.022568
#
#                                 slippage_modifiable Is_blacklisted  \
# Is_closed_source                           0.096956       0.037474
# hidden_owner                               0.027871       0.027871
# anti_whale_modifiable                      0.064038       0.104568
# Is_anti_whale                              0.017023       0.138613
# Is_honeypot                                0.067837        0.15337
# buy_tax                                    0.056606       0.056606
# sell_tax                                    0.09833       0.062867
# slippage_modifiable                             1.0       0.119648
# Is_blacklisted                             0.119648            1.0
# can_take_back_ownership                    0.020821       0.059259
# owner_change_balance                       0.017732       0.224064
# is_airdrop_scam                            0.022568       0.022568
# selfdestruct                                0.08364       0.037578
# trust_list                                 0.022568       0.058031
# is_whitelisted                             0.064038       0.023507
# is_fake_token                              0.179009       0.018463
# illegal_unicode                            0.041283       0.038878
# exploitation                               0.044689       0.044689
# bad_contract                               0.340068       0.140028
# reusing_state_variable                     0.001202       0.121443
# encode_packed_collision                    0.180981       0.100901
# encode_packed_parameters                   0.060861       0.139339
# centralized_risk_medium                     0.06181       0.021674
# centralized_risk_high                       0.18222       0.101947
# centralized_risk_low                       0.060012       0.060012
# event_setter                               0.019219       0.060861
# external_dependencies                        0.0245       0.146999
# immutable_states                           0.065333       0.138832
# reentrancy_without_eth_transfer              0.0004       0.039616
# incorrect_inheritance_order                0.038878       0.201603
# shadowing_local                            0.079632         0.0004
# events_maths                               0.040416       0.120448
#
#                                 can_take_back_ownership  ...  \
# Is_closed_source                               0.104751  ...
# hidden_owner                                   0.182537  ...
# anti_whale_modifiable                          0.128152  ...
# Is_anti_whale                                  0.006489  ...
# Is_honeypot                                    0.085585  ...
# buy_tax                                        0.015447  ...
# sell_tax                                       0.085486  ...
# slippage_modifiable                            0.020821  ...
# Is_blacklisted                                 0.059259  ...
# can_take_back_ownership                             1.0  ...
# owner_change_balance                           0.116131  ...
# is_airdrop_scam                                0.196778  ...
# selfdestruct                                   0.054985  ...
# trust_list                                     0.166132  ...
# is_whitelisted                                 0.115175  ...
# is_fake_token                                  0.237752  ...
# illegal_unicode                                0.102667  ...
# exploitation                                   0.106691  ...
# bad_contract                                   0.040032  ...
# reusing_state_variable                         0.022458  ...
# encode_packed_collision                        0.121795  ...
# encode_packed_parameters                       0.158654  ...
# centralized_risk_medium                        0.083534  ...
# centralized_risk_high                          0.163856  ...
# centralized_risk_low                           0.120096  ...
# event_setter                                   0.038462  ...
# external_dependencies                          0.049029  ...
# immutable_states                               0.049029  ...
# reentrancy_without_eth_transfer                0.020821  ...
# incorrect_inheritance_order                    0.142771  ...
# shadowing_local                                0.059259  ...
# events_maths                                   0.020821  ...
#
#                                 centralized_risk_medium centralized_risk_high  \
# Is_closed_source                               0.060855              0.058468
# hidden_owner                                   0.027108              0.015248
# anti_whale_modifiable                          0.027644              0.094313
# Is_anti_whale                                  0.094313              0.068296
# Is_honeypot                                    0.023667              0.050291
# buy_tax                                        0.055056              0.184094
# sell_tax                                        0.07114               0.07114
# slippage_modifiable                             0.06181               0.18222
# Is_blacklisted                                 0.021674              0.101947
# can_take_back_ownership                        0.083534              0.163856
# owner_change_balance                           0.090542              0.192403
# is_airdrop_scam                                0.130963              0.130963
# selfdestruct                                   0.072139              0.112667
# trust_list                                     0.050122               0.07114
# is_whitelisted                                 0.108948              0.094313
# is_fake_token                                  0.033816              0.086957
# illegal_unicode                                0.024925               0.22593
# exploitation                                   0.095939              0.061338
# bad_contract                                   0.080257              0.160514
# reusing_state_variable                         0.055477              0.024925
# encode_packed_collision                        0.077109              0.077109
# encode_packed_parameters                       0.003213              0.083534
# centralized_risk_medium                             1.0              0.074074
# centralized_risk_high                          0.074074                   1.0
# centralized_risk_low                           0.120386              0.040129
# event_setter                                   0.036948              0.036948
# external_dependencies                          0.016382              0.024574
# immutable_states                                0.06553              0.057339
# reentrancy_without_eth_transfer                  0.0586              0.101947
# incorrect_inheritance_order                    0.095678              0.216282
# shadowing_local                                0.098736              0.101947
# events_maths                                   0.101947               0.06181
#
#                                 centralized_risk_low event_setter  \
# Is_closed_source                            0.029735     0.014284
# hidden_owner                                     0.0     0.028733
# anti_whale_modifiable                       0.081044     0.047043
# Is_anti_whale                               0.040522      0.07462
# Is_honeypot                                      0.0     0.159365
# buy_tax                                     0.085749     0.015447
# sell_tax                                         0.0     0.075808
# slippage_modifiable                         0.060012     0.019219
# Is_blacklisted                              0.060012     0.060861
# can_take_back_ownership                     0.120096     0.038462
# owner_change_balance                        0.080582     0.075808
# is_airdrop_scam                             0.040291     0.035485
# selfdestruct                                0.100995     0.054985
# trust_list                                       0.0     0.166132
# is_whitelisted                              0.040522     0.047043
# is_fake_token                               0.080257     0.077109
# illegal_unicode                             0.220397     0.142771
# exploitation                                0.039193      0.18514
# bad_contract                                     0.0          0.0
# reusing_state_variable                      0.060108     0.102667
# encode_packed_collision                     0.040032     0.038462
# encode_packed_parameters                         0.0     0.038462
# centralized_risk_medium                     0.120386     0.036948
# centralized_risk_high                       0.040129     0.036948
# centralized_risk_low                             1.0     0.040032
# event_setter                                0.040032          1.0
# external_dependencies                        0.08165     0.130744
# immutable_states                            0.163299     0.073544
# reentrancy_without_eth_transfer             0.020004     0.020821
# incorrect_inheritance_order                 0.140253     0.017646
# shadowing_local                             0.060012     0.100901
# events_maths                                0.020004     0.060861
#
#                                 external_dependencies immutable_states  \
# Is_closed_source                             0.109254         0.012139
# hidden_owner                                 0.068945         0.060327
# anti_whale_modifiable                        0.090987         0.157159
# Is_anti_whale                                0.008272         0.157159
# Is_honeypot                                  0.165531         0.015048
# buy_tax                                      0.035007         0.035007
# sell_tax                                     0.016449         0.065795
# slippage_modifiable                            0.0245         0.065333
# Is_blacklisted                               0.146999         0.138832
# can_take_back_ownership                      0.049029         0.049029
# owner_change_balance                         0.016449         0.106917
# is_airdrop_scam                              0.024673         0.098693
# selfdestruct                                 0.049477         0.032985
# trust_list                                   0.016449         0.148039
# is_whitelisted                               0.049629         0.033086
# is_fake_token                                0.106486         0.057339
# illegal_unicode                              0.049078         0.049078
# exploitation                                 0.064002         0.144005
# bad_contract                                 0.040825          0.08165
# reusing_state_variable                       0.294469         0.032719
# encode_packed_collision                      0.089887         0.032686
# encode_packed_parameters                     0.008172         0.032686
# centralized_risk_medium                      0.016382          0.06553
# centralized_risk_high                        0.024574         0.057339
# centralized_risk_low                          0.08165         0.163299
# event_setter                                 0.130744         0.073544
# external_dependencies                             1.0         0.208333
# immutable_states                             0.208333              1.0
# reentrancy_without_eth_transfer              0.106166         0.146999
# incorrect_inheritance_order                   0.00818         0.032719
# shadowing_local                                0.0245         0.179665
# events_maths                                 0.065333         0.057166
#
#                                 reentrancy_without_eth_transfer  \
# Is_closed_source                                        0.08149
# hidden_owner                                           0.098815
# anti_whale_modifiable                                  0.057553
# Is_anti_whale                                          0.023507
# Is_honeypot                                            0.005899
# buy_tax                                                0.099489
# sell_tax                                               0.022568
# slippage_modifiable                                      0.0004
# Is_blacklisted                                         0.039616
# can_take_back_ownership                                0.020821
# owner_change_balance                                   0.103166
# is_airdrop_scam                                        0.103166
# selfdestruct                                           0.043234
# trust_list                                             0.143465
# is_whitelisted                                         0.017023
# is_fake_token                                           0.06181
# illegal_unicode                                        0.041283
# exploitation                                           0.033713
# bad_contract                                           0.020004
# reusing_state_variable                                 0.041283
# encode_packed_collision                                0.060861
# encode_packed_parameters                               0.099299
# centralized_risk_medium                                  0.0586
# centralized_risk_high                                  0.101947
# centralized_risk_low                                   0.020004
# event_setter                                           0.020821
# external_dependencies                                  0.106166
# immutable_states                                       0.146999
# reentrancy_without_eth_transfer                             1.0
# incorrect_inheritance_order                            0.121443
# shadowing_local                                         0.20048
# events_maths                                             0.0004
#
#                                 incorrect_inheritance_order shadowing_local  \
# Is_closed_source                                   0.006554        0.022008
# hidden_owner                                       0.000846        0.196785
# anti_whale_modifiable                               0.03004        0.064038
# Is_anti_whale                                      0.091745        0.023507
# Is_honeypot                                        0.017725        0.005899
# buy_tax                                            0.173526        0.114927
# sell_tax                                           0.174372        0.183764
# slippage_modifiable                                0.038878        0.079632
# Is_blacklisted                                     0.201603          0.0004
# can_take_back_ownership                            0.142771        0.059259
# owner_change_balance                               0.134008        0.058031
# is_airdrop_scam                                    0.108175        0.138629
# selfdestruct                                       0.129911        0.002828
# trust_list                                         0.134008        0.022568
# is_whitelisted                                     0.070636        0.179143
# is_fake_token                                      0.015276        0.098736
# illegal_unicode                                    0.003613        0.239279
# exploitation                                       0.055755        0.033713
# bad_contract                                       0.060108        0.020004
# reusing_state_variable                             0.204336        0.159118
# encode_packed_collision                            0.102667        0.059259
# encode_packed_parameters                           0.137959        0.060861
# centralized_risk_medium                            0.095678        0.098736
# centralized_risk_high                              0.216282        0.101947
# centralized_risk_low                               0.140253        0.060012
# event_setter                                       0.017646        0.100901
# external_dependencies                               0.00818          0.0245
# immutable_states                                   0.032719        0.179665
# reentrancy_without_eth_transfer                    0.121443         0.20048
# incorrect_inheritance_order                             1.0        0.081363
# shadowing_local                                    0.081363             1.0
# events_maths                                       0.121443        0.079632
#
#                                 events_maths
# Is_closed_source                    0.037474
# hidden_owner                        0.014358
# anti_whale_modifiable               0.098083
# Is_anti_whale                       0.145098
# Is_honeypot                          0.15337
# buy_tax                             0.056606
# sell_tax                            0.022568
# slippage_modifiable                 0.040416
# Is_blacklisted                      0.120448
# can_take_back_ownership             0.020821
# owner_change_balance                0.058031
# is_airdrop_scam                     0.259527
# selfdestruct                        0.043234
# trust_list                          0.058031
# is_whitelisted                      0.023507
# is_fake_token                       0.021674
# illegal_unicode                     0.041283
# exploitation                        0.123091
# bad_contract                         0.10002
# reusing_state_variable              0.038878
# encode_packed_collision             0.019219
# encode_packed_parameters            0.060861
# centralized_risk_medium             0.101947
# centralized_risk_high                0.06181
# centralized_risk_low                0.020004
# event_setter                        0.060861
# external_dependencies               0.065333
# immutable_states                    0.057166
# reentrancy_without_eth_transfer       0.0004
# incorrect_inheritance_order         0.121443
# shadowing_local                     0.079632
# events_maths                             1.0
#
# [32 rows x 32 columns]

# %% [markdown]
# Now even though we have the full correlation matrix in front of us, it is very difficult to visualize. One thing that we can do is only display those correlations where value is significantly positive or negative.
#
# But a much better way is to visualize this matrix as a heatmap.

# %%
# Setting the size of the plot
plt.figure(figsize=(12, 10))

# Creating a heatmap
sns.heatmap(phi_matrix.astype(float), annot=False, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap of Phi Coefficients Between Risk Tags')
plt.show()

# %% [markdown]
# You can experiment with a variety of versions of this heatmap to improve visibility of the trends
